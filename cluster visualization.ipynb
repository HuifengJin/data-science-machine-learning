# %% [markdown]
# In \[1\]:
#
#     import numpy as np
#     import pandas as pd
#     import matplotlib.pyplot as plt
#     %matplotlib inline
#     import seaborn as sns
#     import plotly.express as px
#
# In \[2\]:
#
#     df = pd.read_csv('wc_clusters_220803.csv')
#     df
#
# Out\[2\]:
#
# |       | Veh\_VIN\_\#      | Mat\_\#\_M+H\_installed | Date\_Veh\_Repair\_Y/M | M+H\_Proj\_\#\_new | Cust\_2\_Group\_L2 | M+H\_Plant\_2\_Comp\_Code | Veh\_Model\_Year | Veh\_Model\_Code | Veh\_Repair\_1\_Country | Veh\_Dealer\_Code | Veh\_mileage\_(km) | Veh\_Oper\_Hours | Months\_in\_Service | Number of claims | amount\_claimed | cluster\_label |
# |-------|-------------------|-------------------------|------------------------|--------------------|--------------------|---------------------------|------------------|------------------|-------------------------|-------------------|--------------------|------------------|---------------------|------------------|-----------------|----------------|
# | 0     | DD1GX2KCK62006    | 0152000S01              | MAY 2022               | EP-JAG1015-06      | JLR Jaguar         | MHUK                      | 2019             | F-TYPE (X152)    | USA                     | J5438             | 36049              | 0                | 41                  | 1                | 789.66          | 3              |
# | 1     | KL4CJCSMXKB855592 | 0201801524              | FEB 2022               | \#                 | GM Korea           | MHKR                      | 2019             | ENCORE           | USA                     | 13-06514/0        | 52746              | 0                | 35                  | 1                | 39.16           | 1              |
# | 2     | KL4CJGSM8KB867568 | 0201801524              | JUN 2022               | \#                 | GM Korea           | MHKR                      | 2019             | ENCORE           | USA                     | 11-57372/0        | 12786              | 0                | 31                  | 1                | 16.27           | 1              |
# | 3     | 1F65F5KY1J0A22811 | 0213030002              | APR 2022               | \#                 | Ford               | MHMX                      | 2018             | T/Y3             | USA                     | 6116              | 63838              | 0                | 38                  | 1                | 500.39          | 1              |
# | 4     | 1FA6P8CF0L5189184 | 0213030002              | APR 2022               | \#                 | Ford               | MHMX                      | 2020             | C/ZG             | USA                     | 4331              | 11581              | 0                | 16                  | 1                | 165.98          | 1              |
# | ...   | ...               | ...                     | ...                    | ...                | ...                | ...                       | ...              | ...              | ...                     | ...               | ...                | ...              | ...                 | ...              | ...             | ...            |
# | 80218 | 1FTYR1ZM8HKA54862 | UFRFA1916               | MAY 2022               | \#                 | Ford               | MPUS                      | 2017             | T/TH             | USA                     | 6085              | 55439              | 0                | 64                  | 1                | 63.62           | 3              |
# | 80219 | 1FTYR1ZM8KKB35108 | UFRFA1916               | MAY 2022               | \#                 | Ford               | MPUS                      | 2019             | T/TH             | USA                     | 2474              | 42828              | 0                | 33                  | 1                | 33.11           | 1              |
# | 80220 | 1FTYR3XM9GKB56247 | UFRFA1916               | MAY 2022               | \#                 | Ford               | MPUS                      | 2016             | T/TH             | USA                     | 4240              | 71305              | 0                | 71                  | 1                | 54.07           | 3              |
# | 80221 | 1FATP8UH2L5156805 | UFRFA1918               | APR 2022               | \#                 | Ford               | MPUS                      | 2020             | C/ZG             | USA                     | 5780              | 33355              | 0                | 23                  | 1                | 19.35           | 1              |
# | 80222 | 1FA6P8CF7L5101067 | UFRFA1918               | MAY 2022               | \#                 | Ford               | MPUS                      | 2020             | C/ZG             | USA                     | 7501              | 35130              | 0                | 30                  | 1                | 46.02           | 1              |
#
# 80223 rows × 16 columns
#
# In \[7\]:
#
#     df_cluster0 = df[df['cluster_label'] == 0]
#     df_cluster1 = df[df['cluster_label'] == 1]
#     df_cluster2 = df[df['cluster_label'] == 2]
#     df_cluster3 = df[df['cluster_label'] == 3]
#     df_cluster4 = df[df['cluster_label'] == 4]
#     df.cluster_label.value_counts()
#
# Out\[7\]:
#
#     1    60716
#     3    18683
#     0      753
#     2       70
#     4        1
#     Name: cluster_label, dtype: int64
#
# In \[10\]:
#
#     #generate bubble charts and choose top 20 most number of claims part numbers within the cluster
#     def bubble_chart(cluster_df, t):
#         cluster_df['Months_in_Service'] = cluster_df['Months_in_Service'] * cluster_df['Number of claims']
#         cluster_pn = cluster_df.groupby('Mat_#_M+H_installed', as_index=False).agg(
#             total_claims = ('Number of claims', sum),
#             total_months_in_service = ('Months_in_Service', sum),
#             total_amount_claimed = ('amount_claimed', sum)
#         )
#
#         cluster_pn['avg_months_in_service'] = cluster_pn['total_months_in_service']/cluster_pn['total_claims']
#         cluster_pn['avg_amount_claimed'] = cluster_pn['total_amount_claimed']/cluster_pn['total_claims']
#
#         cluster_pn = cluster_pn.sort_values(by='total_claims', ascending=False).head(20)
#         fig = px.scatter(cluster_pn, x="avg_months_in_service", y="avg_amount_claimed", size="total_claims",
#                          color="Mat_#_M+H_installed", hover_name="Mat_#_M+H_installed",
#                          title = t, log_x=True, size_max=60)
#         fig.show()
#         fig.write_html(t + ' 220803.html')
#
# In \[9\]:
#
#     bubble_chart(df_cluster0, "Financially Important Bubbble Chart")
#
#     C:\Users\353983\AppData\Local\Temp\ipykernel_11460\3076591596.py:2: SettingWithCopyWarning:
#
#
#     A value is trying to be set on a copy of a slice from a DataFrame.
#     Try using .loc[row_indexer,col_indexer] = value instead
#
#     See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# In \[12\]:
#
#     bubble_chart(df_cluster1, "Bubbble Chart - high number of claims")
#
# In \[13\]:
#
#     #transform bubble charts into detailed excel file
#     def bubble_chart_detail(cluster_df):
#         cluster_df['Months_in_Service'] = cluster_df['Months_in_Service'] * cluster_df['Number of claims']
#         cluster_pn = cluster_df.groupby('Mat_#_M+H_installed', as_index=False).agg(
#             total_claims = ('Number of claims', sum),
#             total_months_in_service = ('Months_in_Service', sum),
#             total_amount_claimed = ('amount_claimed', sum)
#         )
#
#         cluster_pn['avg_months_in_service'] = cluster_pn['total_months_in_service']/cluster_pn['total_claims']
#         cluster_pn['avg_amount_claimed'] = cluster_pn['total_amount_claimed']/cluster_pn['total_claims']
#
#         cluster_pn = cluster_pn.sort_values(by='total_claims', ascending=False).head(20)
#
#         cluster_pn.drop('total_months_in_service', axis=1, inplace=True)
#         cluster_pn.drop('total_amount_claimed', axis=1, inplace=True)
#
#         cluster_pn = cluster_pn.reset_index(drop=True)
#
#         return cluster_pn
#
# In \[14\]:
#
#     high_noc = bubble_chart_detail(df_cluster1)
#     high_noc = high_noc.round(2)
#
# In \[15\]:
#
#     high_ac = bubble_chart_detail(df_cluster0)
#     high_ac = high_ac.round(2)
#
#     C:\Users\353983\AppData\Local\Temp\ipykernel_11460\696181100.py:2: SettingWithCopyWarning:
#
#
#     A value is trying to be set on a copy of a slice from a DataFrame.
#     Try using .loc[row_indexer,col_indexer] = value instead
#
#     See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# In \[16\]:
#
#     with pd.ExcelWriter('Bubble chart detail 220803.xlsx') as writer:
#         high_noc.to_excel(writer, sheet_name='high number of claims', index=False)
#         high_ac.to_excel(writer, sheet_name='Financially Important claims', index=False)
#
# In \[ \]:
